# %%
# !pip install dash==1.19.0
# !pip install jupyter_dash
# !pip install --upgrade plotly
# !pip install wget
# Out:
# Requirement already satisfied: dash==1.19.0 in c:\users\sabri\anaconda3\lib\site-packages (1.19.0)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\sabri\anaconda3\lib\site-packages (from dash==1.19.0) (1.9.0)
# Requirement already satisfied: Flask>=1.0.4 in c:\users\sabri\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: flask-compress in c:\users\sabri\anaconda3\lib\site-packages (from dash==1.19.0) (1.10.1)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\sabri\anaconda3\lib\site-packages (from dash==1.19.0) (4.11.2)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\sabri\anaconda3\lib\site-packages (from dash==1.19.0) (1.1.2)
# Requirement already satisfied: plotly in c:\users\sabri\anaconda3\lib\site-packages (from dash==1.19.0) (5.3.1)
# Requirement already satisfied: future in c:\users\sabri\anaconda3\lib\site-packages (from dash==1.19.0) (0.18.2)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\sabri\anaconda3\lib\site-packages (from dash==1.19.0) (1.15.0)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\sabri\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\sabri\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\sabri\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\sabri\anaconda3\lib\site-packages (from Flask>=1.0.4->dash==1.19.0) (8.0.1)
# Requirement already satisfied: brotli in c:\users\sabri\anaconda3\lib\site-packages (from flask-compress->dash==1.19.0) (1.0.9)
# Requirement already satisfied: six in c:\users\sabri\appdata\roaming\python\python38\site-packages (from plotly->dash==1.19.0) (1.15.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\sabri\anaconda3\lib\site-packages (from plotly->dash==1.19.0) (8.0.1)
# Requirement already satisfied: colorama in c:\users\sabri\appdata\roaming\python\python38\site-packages (from click>=5.1->Flask>=1.0.4->dash==1.19.0) (0.4.3)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\sabri\anaconda3\lib\site-packages (from Jinja2>=2.10.1->Flask>=1.0.4->dash==1.19.0) (2.0.1)
# Requirement already satisfied: jupyter_dash in c:\users\sabri\anaconda3\lib\site-packages (0.4.0)
# Requirement already satisfied: dash in c:\users\sabri\anaconda3\lib\site-packages (from jupyter_dash) (1.19.0)
# Requirement already satisfied: ansi2html in c:\users\sabri\anaconda3\lib\site-packages (from jupyter_dash) (1.6.0)
# Requirement already satisfied: requests in c:\users\sabri\anaconda3\lib\site-packages (from jupyter_dash) (2.26.0)
# Requirement already satisfied: flask in c:\users\sabri\anaconda3\lib\site-packages (from jupyter_dash) (1.1.2)
# Requirement already satisfied: retrying in c:\users\sabri\anaconda3\lib\site-packages (from jupyter_dash) (1.3.3)
# Requirement already satisfied: ipykernel in c:\users\sabri\anaconda3\lib\site-packages (from jupyter_dash) (6.4.1)
# Requirement already satisfied: ipython in c:\users\sabri\anaconda3\lib\site-packages (from jupyter_dash) (7.27.0)
# Requirement already satisfied: dash-html-components==1.1.2 in c:\users\sabri\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.1.2)
# Requirement already satisfied: dash-table==4.11.2 in c:\users\sabri\anaconda3\lib\site-packages (from dash->jupyter_dash) (4.11.2)
# Requirement already satisfied: dash-core-components==1.15.0 in c:\users\sabri\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.15.0)
# Requirement already satisfied: future in c:\users\sabri\anaconda3\lib\site-packages (from dash->jupyter_dash) (0.18.2)
# Requirement already satisfied: plotly in c:\users\sabri\anaconda3\lib\site-packages (from dash->jupyter_dash) (5.3.1)
# Requirement already satisfied: dash-renderer==1.9.0 in c:\users\sabri\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.9.0)
# Requirement already satisfied: flask-compress in c:\users\sabri\anaconda3\lib\site-packages (from dash->jupyter_dash) (1.10.1)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\sabri\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\sabri\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\sabri\anaconda3\lib\site-packages (from flask->jupyter_dash) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\sabri\anaconda3\lib\site-packages (from flask->jupyter_dash) (8.0.1)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in c:\users\sabri\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (1.4.1)
# Requirement already satisfied: tornado<7.0,>=4.2 in c:\users\sabri\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (6.1)
# Requirement already satisfied: traitlets<6.0,>=4.1.0 in c:\users\sabri\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (5.1.0)
# Requirement already satisfied: ipython-genutils in c:\users\sabri\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (0.2.0)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in c:\users\sabri\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (0.1.2)
# Requirement already satisfied: jupyter-client<8.0 in c:\users\sabri\anaconda3\lib\site-packages (from ipykernel->jupyter_dash) (7.0.1)
# Requirement already satisfied: backcall in c:\users\sabri\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.2.0)
# Requirement already satisfied: pygments in c:\users\sabri\anaconda3\lib\site-packages (from ipython->jupyter_dash) (2.10.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\sabri\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.17.1)
# Requirement already satisfied: pickleshare in c:\users\sabri\anaconda3\lib\site-packages (from ipython->jupyter_dash) (0.7.5)
# Requirement already satisfied: decorator in c:\users\sabri\anaconda3\lib\site-packages (from ipython->jupyter_dash) (5.1.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\sabri\anaconda3\lib\site-packages (from ipython->jupyter_dash) (3.0.20)
# Requirement already satisfied: setuptools>=18.5 in c:\users\sabri\anaconda3\lib\site-packages (from ipython->jupyter_dash) (58.0.4)
# Requirement already satisfied: colorama in c:\users\sabri\appdata\roaming\python\python38\site-packages (from ipython->jupyter_dash) (0.4.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\sabri\anaconda3\lib\site-packages (from requests->jupyter_dash) (1.26.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sabri\anaconda3\lib\site-packages (from requests->jupyter_dash) (2020.6.20)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\sabri\anaconda3\lib\site-packages (from requests->jupyter_dash) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sabri\anaconda3\lib\site-packages (from requests->jupyter_dash) (3.2)
# Requirement already satisfied: six>=1.7.0 in c:\users\sabri\appdata\roaming\python\python38\site-packages (from retrying->jupyter_dash) (1.15.0)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\sabri\anaconda3\lib\site-packages (from jedi>=0.16->ipython->jupyter_dash) (0.7.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\sabri\anaconda3\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter_dash) (2.0.1)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\sabri\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (4.8.1)
# Requirement already satisfied: nest-asyncio>=1.5 in c:\users\sabri\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (1.5.1)
# Requirement already satisfied: entrypoints in c:\users\sabri\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (0.3)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\sabri\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (2.8.2)
# Requirement already satisfied: pyzmq>=13 in c:\users\sabri\anaconda3\lib\site-packages (from jupyter-client<8.0->ipykernel->jupyter_dash) (22.2.1)
# Requirement already satisfied: wcwidth in c:\users\sabri\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter_dash) (0.2.5)
# Requirement already satisfied: brotli in c:\users\sabri\anaconda3\lib\site-packages (from flask-compress->dash->jupyter_dash) (1.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\sabri\anaconda3\lib\site-packages (from plotly->dash->jupyter_dash) (8.0.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\sabri\anaconda3\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client<8.0->ipykernel->jupyter_dash) (228)
# Requirement already satisfied: plotly in c:\users\sabri\anaconda3\lib\site-packages (5.3.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\sabri\anaconda3\lib\site-packages (from plotly) (8.0.1)
# Requirement already satisfied: six in c:\users\sabri\appdata\roaming\python\python38\site-packages (from plotly) (1.15.0)
# Requirement already satisfied: wget in c:\users\sabri\anaconda3\lib\site-packages (3.2)

# %%
import pandas as pd
import dash
import dash_html_components as html
import dash_core_components as dcc
from dash.dependencies import Input, Output
from jupyter_dash import JupyterDash
import plotly.graph_objects as go
import plotly.express as px
import wget

# %%
# !wget "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv"
# Out:
# --2021-11-08 22:10:51--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/spacex_launch_dash.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.63.118.104
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.63.118.104|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3033 (3.0K) [text/csv]
# Saving to: 'spacex_launch_dash.csv.3'
#
#      0K ..                                                    100% 1.41G=0s
#
# 2021-11-08 22:10:52 (1.41 GB/s) - 'spacex_launch_dash.csv.3' saved [3033/3033]

# %%
# Read the airline data into pandas dataframe
spacex_df = pd.read_csv("spacex_launch_dash.csv")
max_payload = spacex_df['Payload Mass (kg)'].max()
min_payload = spacex_df['Payload Mass (kg)'].min()
spacex_df
# Out:
#     Unnamed: 0  Flight Number   Launch Site  \
# 0            0              1   CCAFS LC-40
# 1            1              2   CCAFS LC-40
# 2            2              3   CCAFS LC-40
# 3            3              4   CCAFS LC-40
# 4            4              5   CCAFS LC-40
# 5            5              7   CCAFS LC-40
# 6            6              8   CCAFS LC-40
# 7            7              9   CCAFS LC-40
# 8            8             10   CCAFS LC-40
# 9            9             11   CCAFS LC-40
# 10          10             12   CCAFS LC-40
# 11          11             13   CCAFS LC-40
# 12          12             14   CCAFS LC-40
# 13          13             15   CCAFS LC-40
# 14          14             16   CCAFS LC-40
# 15          15             17   CCAFS LC-40
# 16          16             18   CCAFS LC-40
# 17          17             19   CCAFS LC-40
# 18          18             20   CCAFS LC-40
# 19          19             22   CCAFS LC-40
# 20          20             23   CCAFS LC-40
# 21          21             24   CCAFS LC-40
# 22          22             25   CCAFS LC-40
# 23          23             26   CCAFS LC-40
# 24          24             27   CCAFS LC-40
# 25          25             28   CCAFS LC-40
# 26          26              6   VAFB SLC-4E
# 27          27             21   VAFB SLC-4E
# 28          28             29   VAFB SLC-4E
# 29          29             37   VAFB SLC-4E
# 30          30             40   VAFB SLC-4E
# 31          31             42   VAFB SLC-4E
# 32          32             46   VAFB SLC-4E
# 33          33             49   VAFB SLC-4E
# 34          34             51   VAFB SLC-4E
# 35          35             55   VAFB SLC-4E
# 36          36             30    KSC LC-39A
# 37          37             31    KSC LC-39A
# 38          38             32    KSC LC-39A
# 39          39             33    KSC LC-39A
# 40          40             34    KSC LC-39A
# 41          41             35    KSC LC-39A
# 42          42             36    KSC LC-39A
# 43          43             38    KSC LC-39A
# 44          44             39    KSC LC-39A
# 45          45             41    KSC LC-39A
# 46          46             43    KSC LC-39A
# 47          47             44    KSC LC-39A
# 48          48             54    KSC LC-39A
# 49          49             45  CCAFS SLC-40
# 50          50             47  CCAFS SLC-40
# 51          51             48  CCAFS SLC-40
# 52          52             50  CCAFS SLC-40
# 53          53             52  CCAFS SLC-40
# 54          54             53  CCAFS SLC-40
# 55          55             56  CCAFS SLC-40
#
#                       Mission Outcome  class  Payload Mass (kg)  \
# 0                             Success      0               0.00
# 1                             Success      0               0.00
# 2                             Success      0             525.00
# 3                             Success      0             500.00
# 4                             Success      0             677.00
# 5                             Success      0            3170.00
# 6                             Success      0            3325.00
# 7                             Success      0            2296.00
# 8                             Success      0            1316.00
# 9                             Success      0            4535.00
# 10                            Success      0            4428.00
# 11                            Success      0            2216.00
# 12                            Success      0            2395.00
# 13                            Success      0             570.00
# 14                            Success      0            4159.00
# 15                            Success      0            1898.00
# 16                            Success      0            4707.00
# 17               Failure  (in flight)      1            1952.00
# 18                            Success      1            2034.00
# 19                            Success      0            5271.00
# 20                            Success      1            3136.00
# 21                            Success      1            4696.00
# 22                            Success      1            3100.00
# 23                            Success      0            3600.00
# 24                            Success      1            2257.00
# 25                            Success      1            4600.00
# 26                            Success      0             500.00
# 27                            Success      0             553.00
# 28                            Success      1            9600.00
# 29                            Success      1            9600.00
# 30                            Success      1             475.00
# 31                            Success      1            9600.00
# 32                            Success      0            9600.00
# 33                            Success      0            2150.00
# 34                            Success      0            9600.00
# 35                            Success      0            6460.00
# 36                            Success      1            2490.00
# 37                            Success      0            5600.00
# 38                            Success      1            5300.00
# 39                            Success      1            3696.65
# 40                            Success      0            6070.00
# 41                            Success      1            2708.00
# 42                            Success      1            3669.00
# 43                            Success      0            6761.00
# 44                            Success      1            3310.00
# 45                            Success      1            4990.00
# 46                            Success      1            5200.00
# 47                            Success      1            3500.00
# 48                            Success      1            3600.00
# 49                            Success      1            2205.00
# 50  Success  (payload status unclear)      1            3696.65
# 51                            Success      0            4230.00
# 52                            Success      0            6092.00
# 53                            Success      0            2647.00
# 54                            Success      1             362.00
# 55                            Success      0            5384.00
#
#    Booster Version Booster Version Category
# 0   F9 v1.0  B0003                     v1.0
# 1   F9 v1.0  B0004                     v1.0
# 2   F9 v1.0  B0005                     v1.0
# 3   F9 v1.0  B0006                     v1.0
# 4   F9 v1.0  B0007                     v1.0
# 5          F9 v1.1                     v1.1
# 6          F9 v1.1                     v1.1
# 7          F9 v1.1                     v1.1
# 8          F9 v1.1                     v1.1
# 9          F9 v1.1                     v1.1
# 10   F9 v1.1 B1011                     v1.1
# 11   F9 v1.1 B1010                     v1.1
# 12   F9 v1.1 B1012                     v1.1
# 13   F9 v1.1 B1013                     v1.1
# 14   F9 v1.1 B1014                     v1.1
# 15   F9 v1.1 B1015                     v1.1
# 16   F9 v1.1 B1016                     v1.1
# 17   F9 v1.1 B1018                     v1.1
# 18     F9 FT B1019                       FT
# 19     F9 FT B1020                       FT
# 20   F9 FT B1021.1                       FT
# 21     F9 FT B1022                       FT
# 22   F9 FT B1023.1                       FT
# 23     F9 FT B1024                       FT
# 24   F9 FT B1025.1                       FT
# 25     F9 FT B1026                       FT
# 26  F9 v1.1  B1003                     v1.1
# 27   F9 v1.1 B1017                     v1.1
# 28   F9 FT B1029.1                       FT
# 29   F9 FT B1036.1                       FT
# 30   F9 FT B1038.1                       FT
# 31   F9 B4 B1041.1                       B4
# 32  F9 FT  B1036.2                       FT
# 33  F9 FT  B1038.2                       FT
# 34  F9 B4  B1041.2                       B4
# 35  F9 B4  B1043.2                       B4
# 36   F9 FT B1031.1                       FT
# 37     F9 FT B1030                       FT
# 38  F9 FT  B1021.2                       FT
# 39   F9 FT B1032.1                       FT
# 40     F9 FT B1034                       FT
# 41   F9 FT B1035.1                       FT
# 42  F9 FT  B1029.2                       FT
# 43     F9 FT B1037                       FT
# 44   F9 B4 B1039.1                       B4
# 45   F9 B4 B1040.1                       B4
# 46  F9 FT  B1031.2                       FT
# 47   F9 B4 B1042.1                       B4
# 48  F9 B5  B1046.1                       B5
# 49  F9 FT  B1035.2                       FT
# 50   F9 B4 B1043.1                       B4
# 51  F9 FT  B1032.2                       FT
# 52     F9 B4 B1044                       B4
# 53  F9 B4  B1039.2                       B4
# 54   F9 B4 B1045.1                       B4
# 55  F9 B4  B1040.2                       B4

# %%
# Create a dash application
#app = dash.Dash(__name__)
app = JupyterDash(__name__)
#uniquelaunchsites = spacex_df['Launch Site'].unique().tolist()
#lsites = []
#lsites.append({'label': 'All Sites', 'value': 'All Sites'})
#for site in uniquelaunchsites:
#    lsites.append({'label': site, 'value': site})

# Create an app layout
sites=spacex_df['Launch Site'].unique().tolist()
sites.insert(0,'All Sites')
app.layout = html.Div(children=[html.H1('SpaceX Launch Records Dashboard',
                                        style={'textAlign': 'center', 'color': '#503D36',
                                               'font-size': 40}),




                                dcc.Dropdown(id='site-dropdown',
                                options=[                                   
                                        {'label': 'All Sites', 'value': 'ALL'}, 
                                        {'label': 'CCAFS LC-40', 'value': 'CCAFS LC-40'}, 
                                        {'label': 'VAFB SLC-4E', 'value': 'VAFB SLC-4E'}, 
                                        {'label': 'KSC LC-39A', 'value': 'KSC LC-39A'}, 
                                        {'label': 'CCAFS SLC-40', 'value': 'CCAFS SLC-40'},
                                        ], 
                                    placeholder="Select a Launch Site",
                                    value='All Sites',
                                    searchable=True),
                                
                                html.Br(),


                                html.Div(dcc.Graph(id='success-pie-chart')),
                                
                                html.Br(),

                                html.P("Payload Mass (kg)"),
                                
                                # TASK 3: Add a slider to select payload range
                                dcc.RangeSlider(
                                    id='payload_slider',
                                    min=0,
                                    max=10000,
                                    step=1000,
                                    marks={i: '{}'.format(i) for i in range(0, 10001, 1000)},

                                    value=[min_payload,max_payload]
                                ),

                                html.Div(dcc.Graph(id='success-payload-scatter-chart')),

                                ])
# TASK 2:
# Add a callback function for `site-dropdown` as input, `success-pie-chart` as output

@app.callback(
     Output(component_id='success-pie-chart',component_property='figure'),
     [Input(component_id='site-dropdown',component_property='value')]
)

def get_pie(value):
    filtered_df = spacex_df
    if value == 'All Sites':
        fig = px.pie(filtered_df, values='class', names='Launch Site', title='Total Success Launches By Site')
        return fig

    else:
        filtered_df = spacex_df[spacex_df['Launch Site'] == value].groupby(['Launch Site', 'class']). \
        size().reset_index(name='class count')
        title = f"Total Success Launches for site {value}"
        fig = px.pie(filtered_df,values='class count', names='class', title=title)
        return fig
# TASK 4:
# Add a callback function for `site-dropdown` and `payload-slider` as inputs, `success-payload-scatter-chart` as output

@app.callback( Output(component_id='success-payload-scatter-chart', component_property='figure'),
               [Input(component_id='site-dropdown', component_property='value'),
                Input(component_id='payload_slider',component_property='value')])

def get_payload_chart(launch_site, payload_mass):
    if launch_site == 'All Sites':
        fig = px.scatter(spacex_df[spacex_df['Payload Mass (kg)'].between(payload_mass[0], payload_mass[1])], 
                 x="Payload Mass (kg)",
                 y="class",
                 color="Booster Version Category",
                 hover_data=['Launch Site'],
                 title='Correlation Between Payload and Success for All Sites')
        return fig
    else:
        df = spacex_df[spacex_df['Launch Site']==str(launch_site)]
        fig = px.scatter(df[df['Payload Mass (kg)'].between(payload_mass[0], payload_mass[1])], 
                 x="Payload Mass (kg)",
                 y="class",
                 color="Booster Version Category",
                 hover_data=['Launch Site'],
                 title='Correlation Between Payload and Success for Site {}'.format(launch_site))
        return fig

if __name__ == '__main__':
    app.run_server(mode='jupyterlab', port = 8090 ,dev_tools_ui=True, #debug=True,
              dev_tools_hot_reload =True, threaded=True)
